# %%
import pandas as pd
import numpy as np

# %%
dataMovies = pd.read_csv('tmdb_5000_movies.csv')
dataCredits = pd.read_csv('tmdb_5000_credits.csv')

# %%
dataMovies.shape
# Out:
# (4803, 20)

# %%
dataCredits.shape
# Out:
# (4803, 4)

# %%
# No. of Rows are same

# %%
dataMovies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
dataCredits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
# Lets Merge both datasets

# %%
data = dataMovies.merge(dataCredits,on = 'title')

# %%
data.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
data.shape
# Out:
# (4809, 23)

# %%
# Merged Successfuly

# %%
Storage = data
Storage.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
# Storing Merged data into storage because at some point we might need it

# %%
# Now Selecting Cols that would be helpful for us to design our model
data = data[['movie_id','genres','keywords','overview','tagline','production_companies','title','cast','crew']]
data.head(1)
# Out:
#    movie_id                                             genres  \
# 0     19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                        tagline  \
# 0  Enter the World of Pandora.
#
#                                 production_companies   title  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# movie_id                  0
# genres                    0
# keywords                  0
# overview                  3
# tagline                 844
# production_companies      0
# title                     0
# cast                      0
# crew                      0
# dtype: int64

# %%
# tagline has 844 missing values so we will just drop it and we will remove null rows of overview
data = data.drop('tagline',axis =1)
data
# Out:
#       movie_id                                             genres  \
# 0        19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1          285  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3        49026  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4        49529  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...        ...                                                ...
# 4804      9367  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4805     72766  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4806    231617  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4807    126186                                                 []
# 4808     25975                [{"id": 99, "name": "Documentary"}]
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# ...

# %%
data = data.dropna()
data.head(1)
# Out:
#    movie_id                                             genres  \
# 0     19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
data.head(4)
# Out:
#    movie_id                                             genres  \
# 0     19995  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       285  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    206647  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     49026  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
#
#                                 production_companies  \
# ...

# %%
# As we can see genres, keywords, production_companies, cast and crew are in a weird format, they are like list of dictionaries,
# So we need to handle it too
data['genres'][0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# Even they are string in itself, so first we need to remove string
import ast

# %%
ast.literal_eval(data['genres'][0])
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def removeOuterString(obj):
    return ast.literal_eval(obj)

# %%
data['genres'] = data['genres'].apply(removeOuterString)
data['genres'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3305573420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['genres'] = data['genres'].apply(removeOuterString)
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
data.head(1)
# Out:
#    movie_id                                             genres  \
# 0     19995  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  Avatar
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
data['keywords'] = data['keywords'].apply(removeOuterString)
data['production_companies'] = data['production_companies'].apply(removeOuterString)
data['cast'] = data['cast'].apply(removeOuterString)
data['crew'] = data['crew'].apply(removeOuterString)
data['keywords'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3706262544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = data['keywords'].apply(removeOuterString)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3706262544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['production_companies'] = data['production_companies'].apply(removeOuterString)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3706262544.py:3: SettingWithCopyWarning:
# ...

# %%
# our next step is to extract only keywords (The actual word) from keywords column
data['keywords'] = data['keywords'].apply(lambda x : [i['name'] for i in x])
data['keywords']
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3186868777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = data['keywords'].apply(lambda x : [i['name'] for i in x])
# 0       [culture clash, future, space war, space colon...
# 1       [ocean, drug abuse, exotic island, east india ...
# 2       [spy, based on novel, secret agent, sequel, mi...
# 3       [dc comics, crime fighter, terrorist, secret i...
# 4       [based on novel, mars, medallion, space travel...
#                               ...
# 4804    [united states–mexico barrier, legs, arms, pap...
# 4805                                                   []
# 4806    [date, love at first sight, narration, investi...
# ...

# %%
# So we are now successfully extract our desired words
data.head(1)
# Out:
#    movie_id                                             genres  \
# 0     19995  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [{'name': 'Ingenious Film Partners', 'id': 289...  Avatar
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...

# %%
data['genres'][0]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
# Now we need to do same for genre
data["genres"] = data['genres'].apply(lambda x:[i['name'] for i in x] )
data['genres'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\951316124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["genres"] = data['genres'].apply(lambda x:[i['name'] for i in x] )
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
data.head(1)
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [{'name': 'Ingenious Film Partners', 'id': 289...  Avatar
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...

# %%
data['production_companies'][0]
# Out:
# [{'name': 'Ingenious Film Partners', 'id': 289},
#  {'name': 'Twentieth Century Fox Film Corporation', 'id': 306},
#  {'name': 'Dune Entertainment', 'id': 444},
#  {'name': 'Lightstorm Entertainment', 'id': 574}]

# %%
data['production_companies'] = data['production_companies'].apply(lambda x:[i['name'] for i in x])
data['production_companies'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\378380681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['production_companies'] = data['production_companies'].apply(lambda x:[i['name'] for i in x])
# ['Ingenious Film Partners',
#  'Twentieth Century Fox Film Corporation',
#  'Dune Entertainment',
#  'Lightstorm Entertainment']

# %%
data.head(1)
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...  Avatar
#
#                                                 cast  \
# 0  [{'cast_id': 242, 'character': 'Jake Sully', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe48009251416c750aca23', 'de...

# %%
# Now we need to do same for our cast and crew column
data['cast'][0]
# Out:
# [{'cast_id': 242,
#   'character': 'Jake Sully',
#   'credit_id': '5602a8a7c3a3685532001c9a',
#   'gender': 2,
#   'id': 65731,
#   'name': 'Sam Worthington',
#   'order': 0},
#  {'cast_id': 3,
#   'character': 'Neytiri',
#   'credit_id': '52fe48009251416c750ac9cb',
#   'gender': 1,
#   'id': 8691,
#   'name': 'Zoe Saldana',
#   'order': 1},
#  {'cast_id': 25,
#   'character': 'Dr. Grace Augustine',
#   'credit_id': '52fe48009251416c750aca39',
#   'gender': 1,
#   'id': 10205,
#   'name': 'Sigourney Weaver',
#   'order': 2},
#  {'cast_id': 4,
#   'character': 'Col. Quaritch',
#   'credit_id': '52fe48009251416c750ac9cf',
#   'gender': 2,
#   'id': 32747,
#   'name': 'Stephen Lang',
#   'order': 3},
#  {'cast_id': 5,
#   'character': 'Trudy Chacon',
#   'credit_id': '52fe48009251416c750ac9d3',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 4},
#  {'cast_id': 8,
#   'character': 'Selfridge',
#   'credit_id': '52fe48009251416c750ac9e1',
#   'gender': 2,
# ...

# %%
data['cast'] = data['cast'].apply(lambda x: [i['name']for i in x])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\2340723559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cast'] = data['cast'].apply(lambda x: [i['name']for i in x])

# %%
data['cast'][0]
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Michelle Rodriguez',
#  'Giovanni Ribisi',
#  'Joel David Moore',
#  'CCH Pounder',
#  'Wes Studi',
#  'Laz Alonso',
#  'Dileep Rao',
#  'Matt Gerald',
#  'Sean Anthony Moran',
#  'Jason Whyte',
#  'Scott Lawrence',
#  'Kelly Kilgour',
#  'James Patrick Pitt',
#  'Sean Patrick Murphy',
#  'Peter Dillon',
#  'Kevin Dorman',
#  'Kelson Henderson',
#  'David Van Horn',
#  'Jacob Tomuri',
#  'Michael Blain-Rozgay',
#  'Jon Curry',
#  'Luke Hawker',
#  'Woody Schultz',
#  'Peter Mensah',
#  'Sonia Yee',
#  'Jahnel Curfman',
#  'Ilram Choi',
#  'Kyla Warren',
#  'Lisa Roumain',
#  'Debra Wilson',
#  'Chris Mala',
#  'Taylor Kibby',
#  'Jodie Landau',
#  'Julie Lamm',
#  'Cullen B. Madden',
#  'Joseph Brady Madden',
#  'Frankie Torres',
#  'Austin Wilson',
#  'Sara Wilson',
#  'Tamica Washington-Miller',
#  'Lucy Briant',
#  'Nathan Meister',
#  'Gerry Blair',
#  'Matthew Chamberlain',
#  'Paul Yates',
# ...

# %%
# Now theres seems to be an issue that we migt not need full cast we just filter out 5 main cast members and we know that cast is sorted on ordinal form
data['cast'] = data['cast'].apply(lambda x : x[0:5])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\4079871172.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cast'] = data['cast'].apply(lambda x : x[0:5])

# %%
data['cast'][0]
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Michelle Rodriguez']

# %%
data['crew'][0]
# Out:
# [{'credit_id': '52fe48009251416c750aca23',
#   'department': 'Editing',
#   'gender': 0,
#   'id': 1721,
#   'job': 'Editor',
#   'name': 'Stephen E. Rivkin'},
#  {'credit_id': '539c47ecc3a36810e3001f87',
#   'department': 'Art',
#   'gender': 2,
#   'id': 496,
#   'job': 'Production Design',
#   'name': 'Rick Carter'},
#  {'credit_id': '54491c89c3a3680fb4001cf7',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Sound Designer',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '54491cb70e0a267480001bd0',
#   'department': 'Sound',
#   'gender': 0,
#   'id': 900,
#   'job': 'Supervising Sound Editor',
#   'name': 'Christopher Boyes'},
#  {'credit_id': '539c4a4cc3a36810c9002101',
#   'department': 'Production',
#   'gender': 1,
#   'id': 1262,
#   'job': 'Casting',
#   'name': 'Mali Finn'},
#  {'credit_id': '5544ee3b925141499f0008fc',
#   'department': 'Sound',
#   'gender': 2,
#   'id': 1729,
#   'job': 'Original Music Composer',
#   'name': 'James Horner'},
# ...

# %%
# So in crew we will only select writer and director because rest doesn't matter to general public
data['crew'] = data['crew'].apply( lambda x: [i['name'] for i in x if i['job'] in ['Director', 'Writer']])
data['crew'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\4208718094.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['crew'] = data['crew'].apply( lambda x: [i['name'] for i in x if i['job'] in ['Director', 'Writer']])
# ['James Cameron', 'James Cameron']

# %%
data.head(1)
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...  Avatar
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                              crew
# 0  [James Cameron, James Cameron]

# %%
# def list_to_str(l):
#     return " ".join(l)

# %%
# # Now lets unite all string columns to make corpus like a structure
# ListstrCols = ['genres','keywords','production_companies','cast','crew']

# for i in ListstrCols:
#     data[i] = data[i].apply(list_to_str)
# data['info'] = data['genres'] + data['keywords'] + data['overview'] + data['production_companies'] + data['title'] + data['cast'] + data['crew']
# data.head(1)

# %%
# data['info'][0]

# %%
# There seems to be an issue that our text at some places doesnt differentiate because there's no space, secondly
# Its normally preffered to have text in lower case and also we need to combine Production Companies, cast,genres and crew name
# so model doesnt confuse part of word similar with other e.g James bond has 2 words james anderson also 2 words but because 1 word
# is same betweeb them model will think both are close but in reality one's from movies and other plays cricket

# %%
# data['info'] = data['genres'] + " "+ data['keywords'] + " "+ data['overview'] + " "+ data['production_companies'] + " "+ data['title'] +" "+ data['cast'] +" "+ data['crew']
# data['info'] = data['info'].apply(lower)

# lets comment code and move to the state when we created lists

# %%
data.head(1)
# Out:
#    movie_id                                         genres  \
# 0     19995  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                 production_companies   title  \
# 0  [Ingenious Film Partners, Twentieth Century Fo...  Avatar
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                              crew
# 0  [James Cameron, James Cameron]

# %%
# Now first unite words in keywords,genres,prouction companies, director, cast and crew

# %%
data['genres'].apply(lambda x: [i.replace(" ","") for i in x])
# Out:
# 0       [Action, Adventure, Fantasy, ScienceFiction]
# 1                       [Adventure, Fantasy, Action]
# 2                         [Action, Adventure, Crime]
# 3                   [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, ScienceFiction]
#                             ...
# 4804                       [Action, Crime, Thriller]
# 4805                               [Comedy, Romance]
# 4806               [Comedy, Drama, Romance, TVMovie]
# 4807                                              []
# 4808                                   [Documentary]
# Name: genres, Length: 4806, dtype: object

# %%
data['genres'] = data['genres'].apply(lambda x: [i.replace(" ","") for i in x])
data['keywords'] = data['keywords'].apply(lambda x: [i.replace(" ","") for i in x])
data['production_companies'] = data['production_companies'].apply(lambda x: [i.replace(" ","") for i in x])
data['cast'] = data['cast'].apply(lambda x: [i.replace(" ","") for i in x])
data['crew'] = data['crew'].apply(lambda x: [i.replace(" ","") for i in x])
data.head(1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\1903031004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['genres'] = data['genres'].apply(lambda x: [i.replace(" ","") for i in x])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\1903031004.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = data['keywords'].apply(lambda x: [i.replace(" ","") for i in x])
# ...

# %%
data['genres'][0]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'ScienceFiction']

# %%
data['genres'].apply(lambda x :[i.lower() for i in x])
# Out:
# 0       [action, adventure, fantasy, sciencefiction]
# 1                       [adventure, fantasy, action]
# 2                         [action, adventure, crime]
# 3                   [action, crime, drama, thriller]
# 4                [action, adventure, sciencefiction]
#                             ...
# 4804                       [action, crime, thriller]
# 4805                               [comedy, romance]
# 4806               [comedy, drama, romance, tvmovie]
# 4807                                              []
# 4808                                   [documentary]
# Name: genres, Length: 4806, dtype: object

# %%
data['genres'] = data['genres'].apply(lambda x :[i.lower() for i in x])
data['keywords'] = data['keywords'].apply(lambda x :[i.lower() for i in x])
data['production_companies'] = data['production_companies'].apply(lambda x :[i.lower() for i in x])
data['cast'] = data['cast'].apply(lambda x :[i.lower() for i in x])
data['crew'] = data['crew'].apply(lambda x :[i.lower() for i in x])
data.head(1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\646559764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['genres'] = data['genres'].apply(lambda x :[i.lower() for i in x])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\646559764.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = data['keywords'].apply(lambda x :[i.lower() for i in x])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\646559764.py:3: SettingWithCopyWarning:
# ...

# %%
def tolower(s):
    return s.lower()
    
data['title'] = data['title'].apply(tolower)
data['title']
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\1200714227.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['title'] = data['title'].apply(tolower)
# 0                                         avatar
# 1       pirates of the caribbean: at world's end
# 2                                        spectre
# 3                          the dark knight rises
# 4                                    john carter
#                           ...
# 4804                                 el mariachi
# 4805                                   newlyweds
# 4806                   signed, sealed, delivered
# 4807                            shanghai calling
# 4808                           my date with drew
# ...

# %%
data['overview'] = data['overview'].apply(tolower)
data['overview']
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3770287018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['overview'] = data['overview'].apply(tolower)
# 0       in the 22nd century, a paraplegic marine is di...
# 1       captain barbossa, long believed to be dead, ha...
# 2       a cryptic message from bond’s past sends him o...
# 3       following the death of district attorney harve...
# 4       john carter is a war-weary, former military ca...
#                               ...
# 4804    el mariachi just wants to play his guitar and ...
# 4805    a newlywed couple's honeymoon is upended by th...
# 4806    "signed, sealed, delivered" introduces a dedic...
# ...

# %%
data.head(1)
# Out:
#    movie_id                                        genres  \
# 0     19995  [action, adventure, fantasy, sciencefiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                             overview  \
# 0  in the 22nd century, a paraplegic marine is di...
#
#                                 production_companies   title  \
# 0  [ingeniousfilmpartners, twentiethcenturyfoxfil...  avatar
#
#                                                 cast  \
# 0  [samworthington, zoesaldana, sigourneyweaver, ...
#
#                            crew
# 0  [jamescameron, jamescameron]

# %%
# Now lets again convert list into str
def list_to_str(l):
    return " ".join(l)

data['genres'].apply(list_to_str)
# Out:
# 0       action adventure fantasy sciencefiction
# 1                      adventure fantasy action
# 2                        action adventure crime
# 3                   action crime drama thriller
# 4               action adventure sciencefiction
#                          ...
# 4804                      action crime thriller
# 4805                             comedy romance
# 4806               comedy drama romance tvmovie
# 4807
# 4808                                documentary
# Name: genres, Length: 4806, dtype: object

# %%
data['genres'] = data['genres'].apply(list_to_str)
data['keywords'] = data['keywords'].apply(list_to_str)
data['production_companies'] = data['production_companies'].apply(list_to_str)
data['cast'] = data['cast'].apply(list_to_str)
data['crew'] = data['crew'].apply(list_to_str)
data.head(1)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\714726974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['genres'] = data['genres'].apply(list_to_str)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\714726974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['keywords'] = data['keywords'].apply(list_to_str)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\714726974.py:3: SettingWithCopyWarning:
# ...

# %%
# Now lets join al string columns into 1 as info

# %%
data['info'] = data['genres'] + " "+ data['keywords'] + " "+ data['overview'] + " "+ data['production_companies'] + " "+ data['title'] +" "+ data['cast'] +" "+ data['crew']
data['info'][0]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10256\3722790154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['info'] = data['genres'] + " "+ data['keywords'] + " "+ data['overview'] + " "+ data['production_companies'] + " "+ data['title'] +" "+ data['cast'] +" "+ data['crew']
# ...

# %%
data[['movie_id','title','info']]
# Out:
#       movie_id                                     title  \
# 0        19995                                    avatar
# 1          285  pirates of the caribbean: at world's end
# 2       206647                                   spectre
# 3        49026                     the dark knight rises
# 4        49529                               john carter
# ...        ...                                       ...
# 4804      9367                               el mariachi
# 4805     72766                                 newlyweds
# 4806    231617                 signed, sealed, delivered
# 4807    126186                          shanghai calling
# 4808     25975                         my date with drew
#
#                                                    info
# 0     action adventure fantasy sciencefiction cultur...
# 1     adventure fantasy action ocean drugabuse exoti...
# 2     action adventure crime spy basedonnovel secret...
# ...

# %%
# Now thats our dataset
data_movies = data[['movie_id','title','info']]
data_movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    avatar
# 1       285  pirates of the caribbean: at world's end
# 2    206647                                   spectre
# 3     49026                     the dark knight rises
# 4     49529                               john carter
#
#                                                 info
# 0  action adventure fantasy sciencefiction cultur...
# 1  adventure fantasy action ocean drugabuse exoti...
# 2  action adventure crime spy basedonnovel secret...
# 3  action crime drama thriller dccomics crimefigh...
# 4  action adventure sciencefiction basedonnovel m...

# %%
# Now lets calculate similarity based on info for one movie to another

# %%
data_movies.to_csv('data_movies.csv', index = False)
